# %%
import xarray as xr

# %%
tt = xr.open_dataset(r'data/common/chirts/chirts_tmax_1990_2015.nc', )

# %%
tt.tmax.max()
# Out:
# <xarray.DataArray 'tmax' ()>
# array(0.)

# %%
ds_tmax = xr.open_dataset(r'http://iridl.ldeo.columbia.edu/SOURCES/.UCSB/.CHIRTS/.v1.0/.daily/.global/.0p05/.tmax/Y/%2830N%29%2845N%29RANGEEDGES/X/%2820E%29%2850E%29RANGEEDGES/Y/%2836N%29%2842N%29RANGEEDGES/X/%2826E%29%2845E%29RANGEEDGES/T/%281%20Jan%201990%29%2831%20Dec%202015%29RANGEEDGES/dods')

# %%
cc = xr.open_dataset(r'http://iridl.ldeo.columbia.edu/SOURCES/.UCSB/.CHIRTS/.v1.0/.daily/.global/.0p05/.tmax/Y/%2836N%29%2842N%29RANGEEDGES/X/%2826E%29%2845E%29RANGEEDGES/T/%281%20Jan%201990%29%2831%20Dec%202015%29RANGEEDGES/T/%281%20Jan%201990%29%2831%20Dec%201990%29RANGEEDGES/dods')

# %%
cc.tmax[0]
# Out:
# <xarray.DataArray 'tmax' (Y: 120, X: 380)>
# array([[     nan,      nan,      nan, ..., 6.060076, 6.246797, 6.222333],
#        [     nan,      nan,      nan, ..., 6.660408, 6.593894, 6.25057 ],
#        [     nan,      nan,      nan, ..., 6.82334 , 6.548583, 6.16309 ],
#        ...,
#        [1.257408, 1.116211, 0.845238, ..., 1.907818, 1.538821, 1.087566],
#        [1.041687, 0.805688, 0.57488 , ..., 1.491594, 1.395197, 1.347091],
#        [0.780235, 0.554416, 0.265644, ..., 1.413869, 1.596607, 1.400602]],
#       dtype=float32)
# Coordinates:
#   * Y        (Y) float32 36.02 36.08 36.12 36.17 ... 41.83 41.88 41.92 41.97
#   * X        (X) float32 26.03 26.08 26.12 26.18 ... 44.83 44.88 44.93 44.98
#     T        float32 2.448e+06
# Attributes:
#     pointwidth:  1.0
#     units:       Celsius_scale
#     long_name:   Maximum Temperature

# %%
ds_tmax.isel(T=0)['tmax'].plot()

# %%
ds_tmin = xr.open_dataset(r'http://iridl.ldeo.columbia.edu/SOURCES/.UCSB/.CHIRTS/.v1.0/.daily/.global/.0p05/.tmin/Y/%2830N%29%2845N%29RANGEEDGES/X/%2820E%29%2850E%29RANGEEDGES/Y/%2836N%29%2842N%29RANGEEDGES/X/%2826E%29%2845E%29RANGEEDGES/T/%281%20Jan%201990%29%2831%20Dec%202015%29RANGEEDGES/dods')
# Out:
# Note:Caching=1

# %%
ds_tmax.to_netcdf(r'data/common/chirts/chirts_tmax_1990_2015.nc')
# Out:
# Error:curl error: Timeout was reached
# Error:DAP DATADDS packet is apparently too short

# %%
ds_tmin.to_netcdf(r'data/common/chirts/chirts_tmin_1990_2015.nc')

# %%
ds_tmin
# Out:
# <xarray.Dataset>
# Dimensions:  (T: 12419, Y: 120, X: 380)
# Coordinates:
#   * T        (T) float32 2.445e+06 2.445e+06 2.445e+06 ... 2.458e+06 2.458e+06
#   * Y        (Y) float32 36.02 36.08 36.12 36.17 ... 41.83 41.88 41.92 41.97
#   * X        (X) float32 26.03 26.08 26.12 26.18 ... 44.83 44.88 44.93 44.98
# Data variables:
#     tmin     (T, Y, X) float32 ...
# Attributes:
#     Conventions:  IRIDL

# %%
ds_tmax
# Out:
# <xarray.Dataset>
# Dimensions:  (T: 12419, Y: 120, X: 380)
# Coordinates:
#   * T        (T) float32 2.445e+06 2.445e+06 2.445e+06 ... 2.458e+06 2.458e+06
#   * Y        (Y) float32 36.02 36.08 36.12 36.17 ... 41.83 41.88 41.92 41.97
#   * X        (X) float32 26.03 26.08 26.12 26.18 ... 44.83 44.88 44.93 44.98
# Data variables:
#     tmax     (T, Y, X) float32 ...
# Attributes:
#     Conventions:  IRIDL
