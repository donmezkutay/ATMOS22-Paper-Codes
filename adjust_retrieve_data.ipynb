# %% [markdown]
# # ATMOS 2022 - Adjust and Retrieve Datasets

# %% [markdown]
# -----------

# %% [markdown]
# ## 0. Import Libraries

# %%
from data import *
from utils import *

# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %% [markdown]
# ## 1. Dmsp

# %%
province = 'izmir'
dt = retrieve_dmsp(province)

# %%
dt[0].plot()

# %% [markdown]
# -----------

# %% [markdown]
# ## 2. Population

# %%
province = 'istanbul'
dt = retrieve_population(province)

# %%
dt
# Out:
#    Province      2000      2001      2002      2003      2004      2005  \
# 0  istanbul  11076840  11292009  11495948  11699172  11910733  12128577
#
#        2006      2007      2008  ...      2010      2011      2012      2013  \
# 0  12351506  12573836  12697164  ...  13255685  13624240  13854740  14160467
#
#        2014      2015      2016      2017      2018      2019
# 0  14377018  14657434  14804116  15029231  15067724  15519267
#
# [1 rows x 21 columns]

# %%
dt.attrs
# Out:
# {'data-source': 'population', 'province': 'istanbul'}

# %% [markdown]
# -------

# %% [markdown]
# ## 3. Station

# %%
province = 'istanbul'
dt = retrieve_station(province)

# %%
dt
# Out:
#        İSTANBUL  Month  Day  Hour  17047  17059  17060  17061  17062  17063  \
# 0          2009      1    1     0   -0.6    4.5    1.8    2.8    2.7    0.9
# 1          2009      1    1     1   -1.8    4.2    0.4    3.0    2.8    0.9
# 2          2009      1    1     2   -2.1    4.3    0.5    2.2    2.7    1.0
# 3          2009      1    1     3   -2.3    3.9    0.5    2.1    2.4    1.0
# 4          2009      1    1     4   -2.5    2.5    0.6    1.2    2.0    1.1
# ...         ...    ...  ...   ...    ...    ...    ...    ...    ...    ...
# 87643      2018     12   31    19    2.5    6.7    6.7    4.9    6.3    3.7
# 87644      2018     12   31    20    2.6    4.1    6.3    5.1    6.0    3.6
# 87645      2018     12   31    21    2.8    3.2    6.1    5.0    5.9    2.9
# 87646      2018     12   31    22    2.4    3.4    6.2    4.7    5.7    2.0
# 87647      2018     12   31    23    2.4    2.7    6.0    5.0    5.4    1.5
#
#        17064  17065  17603  17610  17636
# 0        2.8    1.0    3.1    0.9    1.9
# 1        2.5    1.1    3.0    1.0    0.9
# 2        2.8    0.8    2.4    1.1    0.4
# 3        3.1    1.0    1.9    1.1    0.7
# 4        2.9    0.7    1.7    1.0    0.4
# ...      ...    ...    ...    ...    ...
# 87643    5.0    4.1    5.6    5.0    5.6
# 87644    4.5    3.7    5.3    5.2    5.5
# 87645    4.3    3.4    5.0    4.9    5.4
# 87646    4.0    2.6    5.0    4.8    5.5
# 87647    4.0    2.7    5.1    4.7    5.2
#
# [87648 rows x 15 columns]

# %%
dt.attrs
# Out:
# {'data-source': 'station',
#  'var-name': 'T',
#  'unit': 'degC',
#  'province': 'istanbul'}

# %% [markdown]
# ----------

# %% [markdown]
# ## 4. Corine

# %%
province = 'ankara'
dt = retrieve_corine(province)

# %%
dt[-1].plot()

# %% [markdown]
# ## 4. Modis

# %%
province = 'istanbul'
source_type = 'terra'
dt = retrieve_modis(province, source_type)

# %%
dt
# Out:
# <xarray.DataArray (time: 7, y: 125, x: 231)>
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
# ...
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]], dtype=float32)
# Coordinates:
#   * y            (y) float64 5.071e+06 5.07e+06 ... 4.957e+06 4.956e+06
#   * x            (x) float64 3.117e+06 3.118e+06 ... 3.33e+06 3.331e+06
#     band         int64 1
#   * time         (time) datetime64[ns] 2011-12-25 2011-12-26 ... 2011-12-31
#     spatial_ref  int64 0

# %%
dt.mean(dim='time').plot()
